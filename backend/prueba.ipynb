# %%
from app.services import hudson_service
import json
from app.db import logyser

# %%
tab = hudson_service.agregar_stock()

# %%
tabla = logyser.consulta_stock()
tabla.encoding = 'utf-8-sig'

# %%
json.loads(tabla.text)
# Out:
# [{'codigo_cliente': 'GIM-SA',
#   'idproducto': 'MOLI01',
#   'descripcion': 'Molinillo de madera color gris 15cm',
#   'estado': 'CUARENTENA',
#   'cantidad': '2',
#   'fecha_update': '2025-05-10 18:07:11'},
#  {'codigo_cliente': 'GIM-SA',
#   'idproducto': 'MOLI02',
#   'descripcion': 'Molinillo de madera color gris 20cm',
#   'estado': 'CUARENTENA',
#   'cantidad': '1',
#   'fecha_update': '2025-05-10 18:07:11'},
#  {'codigo_cliente': 'GIM-SA',
#   'idproducto': 'MOLI03',
#   'descripcion': 'Molinillo de madera color blanco 15cm',
#   'estado': 'CUARENTENA',
#   'cantidad': '3',
#   'fecha_update': '2025-05-10 18:07:11'},
#  {'codigo_cliente': 'GIM-SA',
#   'idproducto': 'MOLI04',
#   'descripcion': 'Molinillo de madera color blanco 20cm',
#   'estado': 'CUARENTENA',
#   'cantidad': '1',
#   'fecha_update': '2025-05-10 18:07:11'},
#  {'codigo_cliente': 'GIM-SA',
#   'idproducto': 'MOLI05',
#   'descripcion': 'Molinillo de madera color negro 15cm',
#   'estado': 'CUARENTENA',
# ...
